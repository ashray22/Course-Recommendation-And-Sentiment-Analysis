# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import neattext.functions as nfx
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity,linear_kernel

# %%
UDEMY_COUSE_DATA_PATH = r"C:\Users\raksh\Desktop\ashray\Course-Recommendation-And-Sentiment-Analysis\data\udemy_course_data.csv"
UDEMY_2 = r"C:\Users\raksh\Desktop\ashray\Course-Recommendation-And-Sentiment-Analysis\data\udemy (2).csv"

# %%
df1 = pd.read_csv(UDEMY_COUSE_DATA_PATH)
df3 = pd.read_csv(UDEMY_2)

# %%
df3.head(2)
# Out:
#                                         course title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
#
#                                           course url  \
# 0      https://www.udemy.com/course/machinelearning/
# 1  https://www.udemy.com/course/python-for-data-s...
#
#                                   course description               Ratings  \
# 0  Learn to create Machine Learning Algorithms in...  Rating: 4.6 out of 5
# 1  Learn how to use NumPy, Pandas, Seaborn , Matp...  Rating: 4.6 out of 5
#
#           reviews          duration      Lectures course level  \
# 0  161655 reviews  44.5 total hours  320 lectures   All Levels
# 1  119789 reviews    25 total hours  165 lectures   All Levels
#
#                                          instructors
# 0  Kirill Eremenko, Hadelin de Ponteves, Ligency ...
# 1                                      Jose Portilla

# %%
df1.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level content_duration  \
# 0             2147           23            51  All Levels        1.5 hours
# 1             2792          923           274  All Levels         39 hours
#
#     published_timestamp           subject  profit published_date  \
# 0  2017-01-18T20:58:58Z  Business Finance  429400     2017-01-18
# 1  2017-03-09T16:34:20Z  Business Finance  209400     2017-03-09
#
#   published_time  year  month  day
# 0      20:58:58Z  2017      1   18
# 1      16:34:20Z  2017      3    9

# %%
df1 = df1.drop(columns=['course_id', 'is_paid', 'num_subscribers', 'published_timestamp', 'profit', 'published_date', 'published_time', 'year', 'month', 'day'],axis=1)

# %%
df3 = df3.drop(columns=['course description', 'Ratings', 'instructors'])

# %%
df3.columns
# Out:
# Index(['course title', 'course url', 'reviews', 'duration', 'Lectures',
#        'course level'],
#       dtype='object')

# %%
num_values = 2791  # Specify the number of random values you want
random_values = np.random.randint(low=0, high=200, size=num_values)
df4 = pd.DataFrame({'price': random_values})
df4
# Out:
#       price
# 0       137
# 1        43
# 2       174
# 3       182
# 4        67
# ...     ...
# 2786     31
# 2787     45
# 2788    164
# 2789     25
# 2790    150
#
# [2791 rows x 1 columns]

# %%
df3 = pd.concat([df3, df4], axis=1)

# %%
df1.rename(columns={'level':'course level','content_duration':'duration','num_reviews':'reviews','num_lectures':'Lectures'}, inplace=True)

# %%
df3.rename(columns={'course title': 'course_title', 'course url':'url'}, inplace=True)

# %%
df3.head(2)
# Out:
#                                         course_title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
#
#                                                  url         reviews  \
# 0      https://www.udemy.com/course/machinelearning/  161655 reviews
# 1  https://www.udemy.com/course/python-for-data-s...  119789 reviews
#
#            duration      Lectures course level  price
# 0  44.5 total hours  320 lectures   All Levels    137
# 1    25 total hours  165 lectures   All Levels     43

# %%
df1.head(2)
# Out:
#                                         course_title  \
# 0                 Ultimate Investment Banking Course
# 1  Complete GST Course & Certification - Grow You...
#
#                                                  url  price  reviews  \
# 0  https://www.udemy.com/ultimate-investment-bank...    200       23
# 1      https://www.udemy.com/goods-and-services-tax/     75      923
#
#    Lectures course level   duration           subject
# 0        51   All Levels  1.5 hours  Business Finance
# 1       274   All Levels   39 hours  Business Finance

# %%
df3['reviews'] = df3['reviews'].str.replace('reviews', '')
df3['reviews'] = df3['reviews'].str.replace('review', '')
df3['duration'] = df3['duration'].str.replace('total', '')
df3['Lectures'] = df3['Lectures'].str.replace('lectures', '')
df3
# Out:
#                                            course_title  \
# 0     Machine Learning A-Z™: Hands-On Python & R In ...
# 1     Python for Data Science and Machine Learning B...
# 2     The Data Science Course 2022: Complete Data Sc...
# 3     R Programming A-Z™: R For Data Science With Re...
# 4     Deep Learning A-Z™: Hands-On Artificial Neural...
# ...                                                 ...
# 2786   Learn Python along with EDA for Indian beginners
# 2787  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 2788              Python ile Twitter Verilerini Kazımak
# 2789                                    EDA for Neurons
# 2790              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                                     url  reviews     duration  \
# 0         https://www.udemy.com/course/machinelearning/  161655   44.5  hours
# 1     https://www.udemy.com/course/python-for-data-s...  119789     25  hours
# ...

# %%
df3.head(2)
# Out:
#                                         course_title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
#
#                                                  url  reviews     duration  \
# 0      https://www.udemy.com/course/machinelearning/  161655   44.5  hours
# 1  https://www.udemy.com/course/python-for-data-s...  119789     25  hours
#
#   Lectures course level  price
# 0     320    All Levels    137
# 1     165    All Levels     43

# %%
desired_order = ['course_title', 'url', 'price','reviews','duration','Lectures','course level']
df3 = df3[desired_order]
df3.head(2)
# Out:
#                                         course_title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
#
#                                                  url  price  reviews  \
# 0      https://www.udemy.com/course/machinelearning/    137  161655
# 1  https://www.udemy.com/course/python-for-data-s...     43  119789
#
#       duration Lectures course level
# 0  44.5  hours     320    All Levels
# 1    25  hours     165    All Levels

# %%
desired_order_2 = ['course_title','url','price','reviews','duration','Lectures','course level', 'subject']
df1 = df1[desired_order_2]
df1.head(2)
# Out:
#                                         course_title  \
# 0                 Ultimate Investment Banking Course
# 1  Complete GST Course & Certification - Grow You...
#
#                                                  url  price  reviews  \
# 0  https://www.udemy.com/ultimate-investment-bank...    200       23
# 1      https://www.udemy.com/goods-and-services-tax/     75      923
#
#     duration  Lectures course level           subject
# 0  1.5 hours        51   All Levels  Business Finance
# 1   39 hours       274   All Levels  Business Finance

# %%
df_3 = df3.copy()

# %%
df3['subject'] = 'Data Science'
df3.head(2)
# Out:
#                                         course_title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
#
#                                                  url  price  reviews  \
# 0      https://www.udemy.com/course/machinelearning/    137  161655
# 1  https://www.udemy.com/course/python-for-data-s...     43  119789
#
#       duration Lectures course level       subject
# 0  44.5  hours     320    All Levels  Data Science
# 1    25  hours     165    All Levels  Data Science

# %%
df3.head()
# Out:
#                                         course_title  \
# 0  Machine Learning A-Z™: Hands-On Python & R In ...
# 1  Python for Data Science and Machine Learning B...
# 2  The Data Science Course 2022: Complete Data Sc...
# 3  R Programming A-Z™: R For Data Science With Re...
# 4  Deep Learning A-Z™: Hands-On Artificial Neural...
#
#                                                  url  price  reviews  \
# 0      https://www.udemy.com/course/machinelearning/    137  161655
# 1  https://www.udemy.com/course/python-for-data-s...     43  119789
# 2  https://www.udemy.com/course/the-data-science-...    174  111891
# 3        https://www.udemy.com/course/r-programming/    182   47444
# 4         https://www.udemy.com/course/deeplearning/     67   40993
#
#       duration Lectures course level       subject
# 0  44.5  hours     320    All Levels  Data Science
# 1    25  hours     165    All Levels  Data Science
# 2    32  hours     517    All Levels  Data Science
# ...

# %%
# df3['course level'] = df3['course level'].str.replace('Intermediate', 'Intermediate Level')
# df3['course level'] = df3['course level'].str.replace('Beginner', 'Beginner Level')

# %%
# df3['course_title'] = df3['course_title'].astype(str)

# %%
# df3['course_title'] = df3['course_title'].apply(nfx.remove_hashtags)

# %%
# df3['course_title'] = df3['course_title'].apply(nfx.remove_stopwords)
# df3['course_title'] = df3['course_title'].apply(nfx.remove_punctuations)
# df3['course_title'] = df3['course_title'].apply(nfx.remove_numbers)
# df3['course_title'] = df3['course_title'].apply(nfx.remove_special_characters)
# df3

# %%
df = pd.concat([df1,df3],ignore_index=True)
df
# Out:
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 6469   Learn Python along with EDA for Indian beginners
# 6470  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 6471              Python ile Twitter Verilerini Kazımak
# 6472                                    EDA for Neurons
# 6473              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                                     url  price reviews  \
# 0     https://www.udemy.com/ultimate-investment-bank...    200      23
# 1         https://www.udemy.com/goods-and-services-tax/     75     923
# 2     https://www.udemy.com/financial-modeling-for-b...     45      74
# ...

# %%
df = df.dropna(subset=['course_title'])
df = df.dropna(subset=['course level'])

# %%
df.columns
# Out:
# Index(['course_title', 'url', 'price', 'reviews', 'duration', 'Lectures',
#        'course level', 'subject'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# course_title    0
# url             0
# price           0
# reviews         0
# duration        0
# Lectures        0
# course level    0
# subject         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# course_title    0
# url             0
# price           0
# reviews         0
# duration        0
# Lectures        0
# course level    0
# subject         0
# dtype: int64

# %%
df.to_csv('final_data.csv',index=False)

# %%
df.isna().sum()
# Out:
# course_title    0
# url             0
# price           0
# reviews         0
# duration        0
# Lectures        0
# course level    0
# subject         0
# dtype: int64

# %%
df_final= pd.read_csv(r'C:\Users\raksh\Desktop\ashray\Course-Recommendation-And-Sentiment-Analysis\data\Udemy_final.csv')

# %%
df_final
# Out:
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 6452   Learn Python along with EDA for Indian beginners
# 6453  AutoViMLによる分類モデル/回帰モデル作成講座:【AutoML/Python/SIGN...
# 6454              Python ile Twitter Verilerini Kazımak
# 6455                                    EDA for Neurons
# 6456              Görüntü İşleme (OpenCV) Giriş Eğitimi
#
#                                                     url  price  reviews  \
# 0     https://www.udemy.com/ultimate-investment-bank...    200       23
# 1         https://www.udemy.com/goods-and-services-tax/     75      923
# 2     https://www.udemy.com/financial-modeling-for-b...     45       74
# ...

# %%
df_final.columns
# Out:
# Index(['course_title', 'url', 'price', 'reviews', 'duration', 'Lectures',
#        'course level', 'subject'],
#       dtype='object')

# %%
df_final.isna().sum()
# Out:
# course_title    0
# url             0
# price           0
# reviews         0
# duration        0
# Lectures        0
# course level    0
# subject         0
# dtype: int64

# %%
df_final.dropna(inplace=True)

# %%
df_final.isna().sum()
# Out:
# course_title    0
# url             0
# price           0
# reviews         0
# duration        0
# Lectures        0
# course level    0
# subject         0
# dtype: int64

# %%
df.to_csv('Udemy_final_data.csv',index=False)

# %%
df_final= pd.read_csv(r'C:\Users\raksh\Desktop\ashray\Course-Recommendation-And-Sentiment-Analysis\notebooks\Udemy_final_data.csv')
df_final.isna().sum()
# Out:
# course_title    18
# url              0
# price            0
# reviews          0
# duration         0
# Lectures         0
# course level     0
# subject          0
# dtype: int64
